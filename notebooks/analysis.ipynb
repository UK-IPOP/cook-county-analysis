# %%
os.chdir('..')

# %%
import pickle
import pandas as pd
import matplotlib.pyplot as plt
import os
from pandas_profiling import ProfileReport
import plotly.express as px

# %%
df = pd.read_csv('../data/coded_records.csv')
# Out:
# /Users/nick/miniforge3/envs/geo/lib/python3.9/site-packages/IPython/core/interactiveshell.py:3165: DtypeWarning: Columns (21) have mixed types.Specify dtype option on import or set low_memory=False.
#   has_raised = await self.run_ast_nodes(code_ast.body, cell_name,

# %%
lat_long_df = df[['Latitude', 'Longitude', 'new_lat', 'new_long', 'address', 'distance']].copy()
print(f"Total rows: {lat_long_df.shape[0]}")
print(lat_long_df.count())
# Out:
# Total rows: 52710
# Latitude     46148
# Longitude    46148
# new_lat      52706
# new_long     52706
# address      52710
# distance     46145
# dtype: int64

# %%
import numpy as np
lat_long_df['distance'] = lat_long_df.distance.apply(lambda x: x * 5280 if x else np.nan)

# %%
lat_long_df.distance.describe().round(2)
# Out:
# count       46145.00
# mean       231395.61
# std       3057884.48
# min             0.00
# 25%             0.13
# 50%             0.23
# 75%            77.82
# max      57326265.16
# Name: distance, dtype: float64

# %%
lat_long_df.shape
# Out:
# (52710, 6)

# %%
px.box(no_null, y='db_distance', points='all')

# %%
no_null[no_null.db_distance > 5]
# Out:
#         Latitude  Longitude    new_lat    new_long  \
# 11     42.017592 -87.672985  18.776096  100.773935
# 131    41.720481 -87.538839  41.717637  -87.681582
# 1024   41.910219 -87.755950  18.776096  100.773935
# 1025   41.886387 -87.712597  18.776096  100.773935
# 1040   41.947692 -87.656992  18.776096  100.773935
# ...          ...        ...        ...         ...
# 52423  41.792779 -87.706058  41.982022  -87.711589
# 52460  41.815607 -87.689600  41.742070  -87.687718
# 52539  41.926707 -87.702032  41.846344  -87.700102
# 52568  41.905362 -87.725097  41.993519  -87.727627
# 52673  41.970477 -87.686463  41.803343  -87.681773
#
#                                                  address     distance
# 11                        7519 N. PAULINA STREET nan nan  8213.259016
# 131    9645 S. Western/R/O ATI Physical Therapy CHICA...     7.383396
# 1024                              1620 N LARIMEE nan nan  8219.896766
# ...

# %%
profile = ProfileReport(df)
profile.to_file('reports/first_report.html')
# Out:
# ...
# Export report to file: 100%|██████████| 1/1 [00:00<00:00, 56.35it/s]
